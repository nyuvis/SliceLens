# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X, y = make_classification(
    n_samples=1000,
    n_features=20,
    n_informative=10,
    n_redundant=2,
)

# %%
dataset = np.hstack((X, y.reshape((-1, 1))))

# %%
columns = list('abcdefghijklmnopqrst') + ['label']

# %%
df = pd.DataFrame(dataset, columns=columns)

# %%
df['label'] = df['label'].astype(int)

# %%
df
# Out:
#             a         b         c         d         e         f         g  \
# 0   -0.052826  0.628367 -4.367150 -0.301159 -0.721065  1.410286 -0.373288
# 1    0.379668 -0.191017  3.188799  1.285965  0.423014 -0.633663  0.012293
# 2    0.030378  1.348763 -2.812178 -2.980801  0.474578  0.088084  0.225352
# 3   -0.345608 -4.839700 -4.688562  0.249002  1.159118  1.846014 -0.187885
# 4   -1.445896 -1.561816  0.812696  0.776388 -0.993984  1.432760  0.853888
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -0.796920 -1.439643 -7.537797  0.678026  0.269781  0.058043 -0.775918
# 996  0.918319  0.348674  1.232769  0.749854  0.745529 -0.044071  0.068517
# 997  0.487989 -2.099997 -5.095113  1.131802  0.715865 -1.627350  1.264315
# 998 -1.216637 -2.580723  1.593988  0.525903  0.003960  2.055335 -0.941908
# 999 -0.756977 -1.286351 -4.141830 -1.560938 -0.182219  2.281294 -0.097733
#
#             h         i         j  ...         l         m         n  \
# 0   -0.157704 -0.611381  1.417274  ... -1.622767  0.225841 -1.990344
# 1   -2.084039 -1.359948  0.014410  ... -0.643167  0.147002  2.104377
# 2   -1.882450  0.247082 -0.207743  ... -2.145794  0.556576 -1.619035
# 3   -3.350667 -0.150666  1.935402  ... -3.484077 -0.722863 -0.040234
# 4   -0.799482 -0.669848  0.693811  ... -0.263835 -1.052607  1.406574
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  1.016999  2.434007  2.120612  ... -2.137745 -0.804037 -2.305758
# 996  0.926856 -3.782324 -0.966517  ...  1.848769 -1.314353 -1.918213
# 997 -1.818667 -1.082111  2.938538  ... -3.529256  0.325211  0.154648
# 998  0.624840 -0.688644  2.639035  ...  0.211796  0.854752  2.851944
# 999 -4.402685  2.728735  1.101370  ... -1.992085  0.200072 -2.639285
#
#             o         p         q         r         s         t  label
# 0    0.144322 -0.648471  1.470171 -0.173934 -0.204101  1.975734      1
# 1    1.535282  0.858956  0.849677 -3.497800  0.321764 -0.184549      0
# 2    0.430127 -0.618042  1.451984 -0.306080 -1.551119 -0.097940      0
# 3   -0.573470 -1.988910 -0.103314 -2.153560 -1.247666  2.897299      0
# 4    0.939674  0.939120 -1.180331 -0.345437 -0.547574 -0.531142      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 995 -1.999619  1.493628  0.632361  2.916302 -0.530134 -1.008700      1
# 996  0.480515 -0.125193 -0.618369 -1.502699 -3.313918  1.541131      1
# 997  1.156977 -0.116683 -1.223725 -1.408259 -0.230901  0.305931      0
# 998  1.200519 -0.716060  1.240124 -1.681996 -0.639924  1.246110      0
# 999  0.926657 -0.731511 -0.286626 -0.314050  0.934898 -0.048836      1
#
# [1000 rows x 21 columns]

# %%
df.to_csv('synthetic.csv', index=False)
